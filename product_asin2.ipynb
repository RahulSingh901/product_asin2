# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notbook
import seaborn as sns

# %%
df=pd.read_csv('product_asin.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (483354, 10)

# %%
df.head()
# Out:
#     X                                              title parent_asin  \
# 0   1                     Allegra Allergy 45ct + 15 Free  B00JENH5OI
# 1   2  InvoSpa Shiatsu Back Shoulder and Neck Massage...  B0C4L5Y711
# 2   4  Kal 100 Mcg Selenium Yeast Free Tablets, 100 C...  B00020HX5S
# 3   5  Rocky Mountain Oils Cinnamon Bark Essential Oi...  B07K363N3S
# 4  12  Prevail Super Absorbent Underpads, Prevail Sup...  B00ACMDOOA
#
#               categories                      cat1  \
# 0  ['Health & Household'             'Health Care'
# 1  ['Health & Household'   'Wellness & Relaxation'
# 2  ['Health & Household'                 'Vitamins
# 3  ['Health & Household'             'Health Care'
# 4  ['Health & Household'             'Health Care'
#
#                              cat2                               cat3  \
# 0   'Over-the-Counter Medication'                           'Allergy
# 1     'Massage Tools & Equipment'               'Electric Massagers'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483354 entries, 0 to 483353
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   X            483354 non-null  int64
#  1   title        483329 non-null  object
#  2   parent_asin  483354 non-null  object
#  3   categories   483354 non-null  object
#  4   cat1         483354 non-null  object
#  5   cat2         465491 non-null  object
#  6   cat3         449540 non-null  object
#  7   cat4         296294 non-null  object
#  8   cat5         96619 non-null   object
#  9   cat6         22153 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 36.9+ MB

# %%
pd.isnull(df)
# Out:
#             X  title  parent_asin  categories   cat1   cat2   cat3   cat4  \
# 0       False  False        False       False  False  False  False  False
# 1       False  False        False       False  False  False  False  False
# 2       False  False        False       False  False  False  False  False
# 3       False  False        False       False  False  False  False   True
# 4       False  False        False       False  False  False  False   True
# ...       ...    ...          ...         ...    ...    ...    ...    ...
# 483349  False  False        False       False  False  False   True   True
# 483350  False  False        False       False  False  False   True   True
# 483351  False  False        False       False  False  False  False  False
# 483352  False  False        False       False  False  False  False  False
# 483353  False  False        False       False  False  False  False  False
#
#          cat5   cat6
# 0       False   True
# 1        True   True
# ...

# %%
pd.isnull(df).sum()
# Out:
# X                   0
# title              25
# parent_asin         0
# categories          0
# cat1                0
# cat2            17863
# cat3            33814
# cat4           187060
# cat5           386735
# cat6           461201
# dtype: int64

# %%
df.shape
# Out:
# (483354, 10)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22150, 10)

# %%
df.shape
# Out:
# (22150, 10)

# %%
df.columns
# Out:
# Index(['X', 'title', 'parent_asin', 'categories', 'cat1', 'cat2', 'cat3',
#        'cat4', 'cat5', 'cat6'],
#       dtype='object')

# %%
df.rename(columns={'cat4':'vitamins'})
# Out:
#              X                                              title parent_asin  \
# 15          32              Imak A10166 Mouse Wrist Cushion, Gray  B00IELVYK2
# 45          80  Elbow Brace - Elbow Sleeve - Compression Arm S...  B07567Z54K
# 95         161  Stick Safe Walking Stick Holder, pack of 2 tie...  B07GQTL3GQ
# 96         162  TEKOMVO Posture Corrector for Women and Men, B...  B0BHMXWCJW
# 106        179  Back Posture Corrector Brace for Women Men and...  B07BGWPS8N
# ...        ...                                                ...         ...
# 483231  797344  Furniture Clear Edge & Corner Protector for Ch...  B07G6ZFFTH
# 483250  797386                                           Bed Cane  B000209XEM
# 483303  797480  DonJoy Performance ANAFORM Double Wrist Wrap S...  B010PU64G8
# 483333  797527  LG G5 Case with Free Screen Protector,Funyye S...  B01M304JPQ
# 483351  797560  JAPAN SOLUTIONS 3D Memory Foam Lumbar Support ...  B01GBOXKSC
#
# ...

# %%
df.describe()
# Out:
#                    X
# count   22150.000000
# mean   398333.800722
# std    232503.085305
# min        32.000000
# 25%    194460.250000
# 50%    397089.000000
# 75%    602928.500000
# max    797560.000000

# %%
df[['X','parent_asin','categories']].describe()
# Out:
#                    X
# count   22150.000000
# mean   398333.800722
# std    232503.085305
# min        32.000000
# 25%    194460.250000
# 50%    397089.000000
# 75%    602928.500000
# max    797560.000000

# %%
df.columns
# Out:
# Index(['X', 'title', 'parent_asin', 'categories', 'cat1', 'cat2', 'cat3',
#        'cat4', 'cat5', 'cat6'],
#       dtype='object')

# %%
ax=sns.countplot(x='cat5',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x='cat4', data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# df.groupby(['cat6'] as_index=False)['categories'].sum().sort_values(by='categories', ascending= false)

# %%
df.columns
# Out:
# Index(['X', 'title', 'parent_asin', 'categories', 'cat1', 'cat2', 'cat3',
#        'cat4', 'cat5', 'cat6'],
#       dtype='object')

# %%
df.groupby(['cat6'] as_index=False)['X'].sum().sort_values(by='X', ascendig=False)

# %%
df.groupby(['cat6'], as_index=False)['categories'].sum().sort_values(by='categories', ascending=False)
# Out:
#                        cat6                                         categories
# 24   Organizers & Pouches']  ['Mobility & Daily Living Aids'['Mobility & Da...
# 10           'Crutch Pads']  ['Medical Supplies & Equipment'['Medical Suppl...
# 7           'Cane Holders']  ['Medical Supplies & Equipment'['Medical Suppl...
# 23                 'Trays']  ['Medical Supplies & Equipment'['Medical Suppl...
# 6       'Cane Flashlights']  ['Medical Supplies & Equipment'['Medical Suppl...
# 1            'Back Braces']  ['Health & Household'['Health & Household'['He...
# 18   'Hand & Wrist Braces']  ['Health & Household'['Health & Household'['He...
# 8                  'Canes']  ['Health & Household'['Health & Household'['He...
# 19       'Lumbar Supports']  ['Health & Household'['Health & Household'['He...
# 14          'Elbow Braces']  ['Health & Household'['Health & Household'['He...
# 22     'Shoulder Supports']  ['Health & Household'['Health & Household'['He...
# ...

# %%
df.groupby(['cat6'], as_index=False)['X'].sum().sort_values(by='X', ascending=False)
# Out:
#                        cat6           X
# 1            'Back Braces']  2174318937
# 18   'Hand & Wrist Braces']  1152638513
# 8                  'Canes']  1026566839
# 19       'Lumbar Supports']   904162013
# 14          'Elbow Braces']   830771514
# 22     'Shoulder Supports']   589682255
# 21      'Pain Relief Rubs']   536526373
# 17        'Finger Splints']   409729545
# 0           'Arm Supports']   344569073
# 15           'Feet & Tips']   188646551
# 5       'Bedside Commodes']   120819804
# 11              'Crutches']   104229048
# 24   Organizers & Pouches']    79340659
# 20          'Male Urinals']    64052348
# 4                'Bedpans']    50392983
# 13                'Dryers']    33379290
# 12           'Cup Holders']    32600561
# 10           'Crutch Pads']    31736808
# 3          'Bathtub Rails']    30171851
# 23                 'Trays']    28632487
# 7           'Cane Holders']    26530991
# 16        'Female Urinals']    25109805
# ...

# %%
df.columns
# Out:
# Index(['X', 'title', 'parent_asin', 'categories', 'cat1', 'cat2', 'cat3',
#        'cat4', 'cat5', 'cat6'],
#       dtype='object')

# %%
ax=sns.countplot(data=df, x='cat6',hue='categories')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(data=df, x='cat5')
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(data=df, x='cat4')
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.columns
# Out:
# Index(['X', 'title', 'parent_asin', 'categories', 'cat1', 'cat2', 'cat3',
#        'cat4', 'cat5', 'cat6'],
#       dtype='object')
